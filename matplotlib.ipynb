# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# %matplotlib inline 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
x = np.random.randint(10,size=5)
y = np.random.randint(10,size=5)

plt.plot(x,y)

# %%
# 1st method 
# plots some figure
fig = plt.figure()

# Adds some axes 
axes = fig.add_subplot() 

plt.show()

# %%
# 2nd method 
fig = plt.figure()
ax = fig.add_axes([1,1,1,1])
ax.plot(x,y)

# %%
# 3rd method(recommended to use)

fig , ax = plt.subplots()
ax.plot(x,y)  #add some data

# %% [markdown]
# # Matplotlib WorkFlow Example

# %%
# import matplotlib and get it ready to be used in jupyter 
# %matplotlib inline 
import matplotlib.pyplot as plt 

# Prepare data 
x = [1,2,3,4]
y = [11,22,33,44]

# setup plot 

fig , axes = plt.subplots(figsize=(10,10))  #width and height 

axes.plot(x,y)

# Customize your plot 

axes.set(title="Simple Plot" , 
        xlabel="X-Axis" , 
        ylabel = "Y-Axis")


# save and show the fig(you save the whole figure)

fig.savefig("/kaggle/working/sample.png")

# %% [markdown]
# ## Making Figures with Numpy Arrays
# we want :
# * Line plots
# * Scatter plot
# * Bar plot
# * Histogram
# * Subplots

# %% [markdown]
# <!-- Line Plot -->

# %%
# Line plot
import numpy as np 

# linspace Return evenly spaced numbers over a specified interval.(start , stop ,number of samples to be generated )

x = np.linspace(0,10,100)
fig , ax = plt.subplots(figsize=(10,5))
ax.plot(x , x**2)

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt 

x = np.linspace(0, 2 * np.pi, 100)

y = np.sin(x)




fig , ax = plt.subplots(figsize=(10,5))
ax.plot(x,y)

# %%
# Scatter plot 

# x = np.linspace(0, 10, 100) 

fig , ax = plt.subplots()
ax.scatter(x,np.sin(x))

# %%
# Making a plot from dictionary 
# Making a bar plot 

nut_butter_prices = {
    "Almond_butter" : 10 , 
    "Peanut_butter" : 8 , 
    "Cashew_butter" : 15
}

fig , ax = plt.subplots()

ax.bar(nut_butter_prices.keys() , nut_butter_prices.values())

ax.set(title="Nut Butter Prices" ,
      xlabel="Butter" , 
      ylabel="Prices") ;

# %%
fig , ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()) , list(nut_butter_prices.values()))
# Out:
# <BarContainer object of 3 artists>

# %%
x = np.random.randn(1000) #Generates 1000 random numbers from a standard normal distribution 

fig , ax = plt.subplots()
ax.hist(x)
# Out:
# (array([  2.,  21.,  57., 129., 220., 269., 184.,  74.,  33.,  11.]),
#  array([-3.34004256, -2.69379538, -2.04754821, -1.40130103, -0.75505386,
#         -0.10880668,  0.5374405 ,  1.18368767,  1.82993485,  2.47618203,
#          3.1224292 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Two options for Subplots

# %%
# Subplot option 1 

fig , ((ax1 , ax2) , (ax3 , ax4)) = plt.subplots(nrows=2 , 
                                                  ncols = 2 , 
                                                  figsize=(10,5))

x = np.linspace(0,10,100) ; 

ax1.plot(x , x/2)

ax2.scatter(np.random.random(10) , np.random.random(10)) ; 

ax3.bar(nut_butter_prices.keys() , nut_butter_prices.values())

ax4.hist(np.random.randn(10000))
# Out:
# (array([  15.,  144.,  632., 1712., 2819., 2668., 1458.,  452.,   92.,
#            8.]),
#  array([-3.69588379, -2.93955665, -2.1832295 , -1.42690236, -0.67057522,
#          0.08575193,  0.84207907,  1.59840622,  2.35473336,  3.11106051,
#          3.86738765]),
#  <BarContainer object of 10 artists>)

# %%
# subplots option 2 

fig , ax = plt.subplots(nrows = 2 , ncols = 2 , figsize = (10,5))


ax[0][0].plot(x , x/2)

ax[0][1].scatter(np.random.random(10) , np.random.random(10))

ax[1][0].bar(nut_butter_prices.keys() , nut_butter_prices.values())

ax[1][1].hist(np.random.randn(10000))
# Out:
# (array([   4.,  116.,  619., 2022., 3269., 2673., 1057.,  205.,   31.,
#            4.]),
#  array([-4.05106243, -3.18994015, -2.32881787, -1.46769559, -0.60657331,
#          0.25454897,  1.11567125,  1.97679353,  2.83791581,  3.69903809,
#          4.56016037]),
#  <BarContainer object of 10 artists>)
